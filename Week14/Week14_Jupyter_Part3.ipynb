# %% [markdown]
# # Week 14 Part 3
# #### How to:
#
# * Use various Jupyter Notebook commands

# %%
# %pwd
# Out:
# 'C:\\Users\\pmuhuri'

# %%
# !python --version
# Out:
# Python 3.7.1

# %%
# !jupyter --version
# Out:
# 4.4.0

# %%
import sys
# !{sys.executable} -m pip install pandas-profiling
