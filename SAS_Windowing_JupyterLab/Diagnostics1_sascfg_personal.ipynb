# %% [markdown]
# ## Instructions and Diagnostics
# #### (Running Licensed SAS in JupyterLab) - Notes compiled by Pradip K. Muhuri
# * sascfg_personal.py configurations
# * SASPy
# * sas_kernel
# * Python
# * Anaconda
# * Jupyter Notebook

# %% [markdown]
# ##### Important Note from sastpw:
#
# ["Be sure your configuration is in your sascfg_personal.py file, not the example sascfg.py file that is part of the saspy repo, because sascfg.py can be overwritten when you do this. That's why you put your configurations in the _personal file so they don't get clobbered when you upgrade!"](https://communities.sas.com/t5/Developers/SASPy-How-to-access-a-library-which-is-unassigned/td-p/497589)

# %% [markdown]
# ##### [Instructions: How to install SASPy Kernel for Jupyter Notebooks and Jupyter Lab](https://communities.sas.com/t5/SAS-Communities-Library/Installing-SASPy-Kernel-for-Jupyter-Notebooks-and-Jupyter-Lab/ta-p/464873)

# %% [markdown]
# ##### Don't forget this (part of the instructions above): Add sspiauth.dll To Your System PATH Environment Variable
# ##### Locate the sspiauth.dll file for your SAS install. It is probably here: C:\Program Files\SASHome\SASFoundation\9.4\core\sasext

# %% [markdown]
# ##### To install saspy from the command line:
# pip install saspy
#
# ##### To uninstall saspy from the command line:
# pip uninstall saspy

# %% [markdown]
# ##### To install `sas_kernel` from the command line:
# pip install sas_kernel
#
# ##### If your `pip` does not map `Python3` you may have to use `pip3`.

# %% [markdown]
# ##### Verify that the sas_kernel is installed by issuing the following from the command lined
# jupyter kernelspec list

# %% [markdown]
# ### List out the kernels and associated folders

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   ir         C:\Users\Pradip.Muhuri\AppData\Roaming\jupyter\kernels\ir
#   python3    C:\Users\Pradip.Muhuri\AppData\Roaming\jupyter\kernels\python3
#   sas        C:\Users\Pradip.Muhuri\AppData\Roaming\jupyter\kernels\sas

# %% [markdown]
# ### Find out which Python I am using

# %%
# !python --version
# Out:
# Python 3.7.3

# %%
import sys
sys.path

# %% [markdown]
# ### Find out which Anaconda I am using

# %%
conda list anaconda$
# Out:
# # packages in environment at C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3:
# #
# # Name                    Version                   Build  Channel
# anaconda                  2019.03                  py37_0
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: The conda.compat module is deprecated and will be removed in a future release.

# %% [markdown]
# ### List out the current environments details

# %%
conda info
# Out:
#      active environment : base
#     active env location : C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3
#             shell level : 1
#        user config file : C:\Users\Pradip.Muhuri\.condarc
#  populated config files : C:\Users\Pradip.Muhuri\.condarc
#           conda version : 4.6.11
#     conda-build version : 3.17.8
#          python version : 3.7.3.final.0
#        base environment : C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/free/win-64
#                           https://repo.anaconda.com/pkgs/free/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
# ...

# %% [markdown]
# ### List out your environments

# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                  *  C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3
#
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: The conda.compat module is deprecated and will be removed in a future release.

# %% [markdown]
# ### List out the Jupyter config directories

# %%
# !jupyter --paths
# Out:
# config:
#     C:\Users\Pradip.Muhuri\.jupyter
#     C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3\etc\jupyter
#     C:\ProgramData\jupyter
# data:
#     C:\Users\Pradip.Muhuri\AppData\Roaming\jupyter
#     C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3\share\jupyter
#     C:\ProgramData\jupyter
# runtime:
#     C:\Users\Pradip.Muhuri\AppData\Roaming\jupyter\runtime

# %%
# %quickref

# %% [markdown]
# ### List out the subdirectories of the "kernels" folder.

# %%
import os
for p in os.listdir("C:\\Users\\Pradip.Muhuri\\AppData\\Roaming\\Jupyter\\kernels"):
    print(p)
# Out:
# ir
# python3
# sas

# %% [markdown]
# ### Find out the .exe files under the ... anaconda3 folder

# %%
import glob
for name in glob.glob('C:\\Users\\pradip.muhuri\\AppData\\Local\\Continuum\\anaconda3\\*.exe'):
    print(name)
# Out:
# C:\Users\pradip.muhuri\AppData\Local\Continuum\anaconda3\python.exe
# C:\Users\pradip.muhuri\AppData\Local\Continuum\anaconda3\pythonw.exe
# C:\Users\pradip.muhuri\AppData\Local\Continuum\anaconda3\Uninstall-Anaconda3.exe

# %% [markdown]
# ### List out the subdirectories (relevant to the configuration of sascfg_personal.py) from a certain folder.

# %%
import os
for p in os.listdir("C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products"):
    print(p)
# Out:
# cfgwizard__94530__prt__xx__sp0__1
# deploywiz__94530__prt__xx__sp0__1
# privatejre__99572__wx6__xx__sp0__1
# sampleplans__94530__prt__xx__sp0__1
# securejava__94120_cd081__prt__xx__sp0__1
# securejava__94120__prt__xx__sp0__1

# %% [markdown]
# ### List out the subdirectory names and file names from a certain folder.

# %%
import os
for p in os.listdir("C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products\\deploywiz__94530__prt__xx__sp0__1"):
    print(p)
# Out:
# deploywiz
# deploywiz.exe
# deploywiz.ini
# deploywiz.rexx
# deploywiz.sh

# %% [markdown]
# ### List out selected .jar files (relevant to the configuration of sascfg_personal.py) from the relvant folder.

# %%
import os
myfiles = ['sas.svc.connection.jar', 'log4j.jar', 'sas.security.sspi.jar', 'sas.core.jar']
for filename in myfiles:
    print(os.path.join('C:\\Program Files\\SASHome\\SASDeploymentManager\\9.4\\products\\deploywiz__94530__prt__xx__sp0__1\\deploywiz', 
    filename))
# Out:
# C:\Program Files\SASHome\SASDeploymentManager\9.4\products\deploywiz__94530__prt__xx__sp0__1\deploywiz\sas.svc.connection.jar
# C:\Program Files\SASHome\SASDeploymentManager\9.4\products\deploywiz__94530__prt__xx__sp0__1\deploywiz\log4j.jar
# C:\Program Files\SASHome\SASDeploymentManager\9.4\products\deploywiz__94530__prt__xx__sp0__1\deploywiz\sas.security.sspi.jar
# C:\Program Files\SASHome\SASDeploymentManager\9.4\products\deploywiz__94530__prt__xx__sp0__1\deploywiz\sas.core.jar

# %% [markdown]
# ### Test the SAS connection using the SASPy module (Python Notebook)

# %%
import saspy
import pandas as pd
sas = saspy.SASsession(cfgname='winlocal')
w_class = sas.sasdata("CLASS","SASHELP")
w_class.describe()
# Out:
# SAS Connection established. Subprocess id is 2380
#   Variable   N  NMiss  Median        Mean     StdDev   Min   P25   P50    P75  \
# 0      Age  19      0    13.0   13.315789   1.492672  11.0  12.0  13.0   15.0
# 1   Height  19      0    62.8   62.336842   5.127075  51.3  57.5  62.8   66.5
# 2   Weight  19      0    99.5  100.026316  22.773933  50.5  84.0  99.5  112.5
#
#    Max
# 0   16
# 1   72
# 2  150

# %% [markdown]
# ### Locate the sascfg_personal.py file, if it exists, using autocfg.py from within Python

# %%
from saspy import autocfg
autocfg.main()
# Out:
# CFGFILE ALREADY EXISTS: C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3\lib\site-packages\saspy\sascfg_personal.py

# %% [markdown]
# ### Retrieve the content of the sascfg_personal.py

# %%
fd = open(r'C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3\lib\site-packages\saspy\sascfg_personal.py')
print(fd.read())
fd.close()
# Out:
# #
# # Copyright SAS Institute
# #
# #  Licensed under the Apache License, Version 2.0 (the License);
# #  you may not use this file except in compliance with the License.
# #  You may obtain a copy of the License at
# #
# #      http://www.apache.org/licenses/LICENSE-2.0
# #
# #  Unless required by applicable law or agreed to in writing, software
# #  distributed under the License is distributed on an "AS IS" BASIS,
# #  WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# #  See the License for the specific language governing permissions and
# #  limitations under the License.
# #
#
# # THIS IS AN EXAMPLE CONFIG FILE. PLEASE CREATE YOUR OWN sascfg_personal.py FILE USING THE APPROPRIATE TEMPLATES FROM BELOW
# # SEE THE CONFIGURATION DOC AT https://sassoftware.github.io/saspy/install.html#configuration
#
#
# # Configuration Names for SAS - python List
# # This is the list of allowed configuration definitions that can be used. The definition are defined below.
# ...

# %% [markdown]
# ### List out the environmental variables and their respective values, one row for each variable
# ### (Method 1)

# %%
import os
for k, v in os.environ.items():
    print(f'{k}={v}')
# Out:
# ALLUSERSPROFILE=C:\ProgramData
# APPDATA=C:\Users\Pradip.Muhuri\AppData\Roaming
# COMMONPROGRAMFILES=C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86)=C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432=C:\Program Files\Common Files
# COMPUTERNAME=HHSLFG772N2
# COMSPEC=C:\windows\system32\cmd.exe
# CONDA_DEFAULT_ENV=base
# CONDA_EXE=C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3\Scripts\conda.exe
# CONDA_PROMPT_MODIFIER=(base)
# CONDA_ROOT=C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3
# CONDA_SHLVL=1
# DADIR=C:\Program Files (x86)\CheckPoint\Endpoint Security\Endpoint Common
# DRIVERDATA=C:\Windows\System32\Drivers\DriverData
# FPS_BROWSER_APP_PROFILE_STRING=Internet Explorer
# FPS_BROWSER_USER_PROFILE_STRING=Default
# HOMEDRIVE=C:
# HOMEPATH=\Users\Pradip.Muhuri
# LOCALAPPDATA=C:\Users\Pradip.Muhuri\AppData\Local
# LOGONSERVER=\\ITIO-PKL-DC08
# MAS_PYPATH=c:\Users\pradip.muhuri\AppData\Local\Continuum\anaconda3\python.exe
# NUMBER_OF_PROCESSORS=8
# ...

# %% [markdown]
# ### List out the environmental variables and their respective values, one row for each variable
# #### (Method 2)

# %%
import os
for a in os.environ:
    print('Var: ', a, 'Value: ', os.getenv(a))
print("all done")
# Out:
# Var:  ALLUSERSPROFILE Value:  C:\ProgramData
# Var:  APPDATA Value:  C:\Users\Pradip.Muhuri\AppData\Roaming
# Var:  COMMONPROGRAMFILES Value:  C:\Program Files\Common Files
# Var:  COMMONPROGRAMFILES(X86) Value:  C:\Program Files (x86)\Common Files
# Var:  COMMONPROGRAMW6432 Value:  C:\Program Files\Common Files
# Var:  COMPUTERNAME Value:  HHSLFG772N2
# Var:  COMSPEC Value:  C:\windows\system32\cmd.exe
# Var:  CONDA_DEFAULT_ENV Value:  base
# Var:  CONDA_EXE Value:  C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3\Scripts\conda.exe
# Var:  CONDA_PROMPT_MODIFIER Value:  (base)
# Var:  CONDA_ROOT Value:  C:\Users\Pradip.Muhuri\AppData\Local\Continuum\anaconda3
# Var:  CONDA_SHLVL Value:  1
# Var:  DADIR Value:  C:\Program Files (x86)\CheckPoint\Endpoint Security\Endpoint Common
# Var:  DRIVERDATA Value:  C:\Windows\System32\Drivers\DriverData
# Var:  FPS_BROWSER_APP_PROFILE_STRING Value:  Internet Explorer
# Var:  FPS_BROWSER_USER_PROFILE_STRING Value:  Default
# ...
